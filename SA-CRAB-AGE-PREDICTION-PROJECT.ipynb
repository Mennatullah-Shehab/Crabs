# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt 
# %matplotlib inline 
import seaborn as sb
from scipy import stats
import matplotlib.pyplot as plt
from collections import Counter
import csv
import scipy.stats as stats
import statsmodels.api as sm

import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
DF = pd.read_csv('CrabAgePrediction.csv')
DF
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11232/1665263897.py in <module>
# ----> 1 DF = pd.read_csv('CrabAgePrediction.csv')
#       2 DF
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# OSError: [Errno 22] Invalid argument: 'CrabAgePrediction.csv'

# %%
G = 'I'
df = DF[DF['Sex'] != G]
df
# Out:
#      Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0      F  1.4375    1.1750  0.4125  24.635715       12.332033        5.584852
# 1      M  0.8875    0.6500  0.2125   5.400580        2.296310        1.374951
# 3      F  1.1750    0.8875  0.2500  13.480187        4.748541        2.282135
# 5      F  1.5500    1.1625  0.3500  28.661344       13.579410        6.761356
# 6      F  1.3000    1.0000  0.3250  17.704263        6.095142        5.854172
# ...   ..     ...       ...     ...        ...             ...             ...
# 3885   F  1.1875    0.9500  0.3375  13.777857        4.918638        1.984465
# 3886   F  1.3250    1.0250  0.3625  23.402512       10.631063        5.783298
# 3887   F  1.7500    1.3750  0.4250  47.740558       21.361348        9.256112
# 3888   F  1.4625    1.1375  0.3250  24.819987       11.651644        5.854172
# 3889   F  1.5500    1.2125  0.4375  34.458817       15.450477        7.172423
#
#       Shell Weight  Age
# 0         6.747181    9
# 1         1.559222    6
# 3         5.244657   10
# 5         7.229122    8
# 6         4.819415   15
# ...            ...  ...
# 3885      5.244657    7
# 3886      6.945627    9
# 3887      9.071840   11
# 3888      6.378637    8
# 3889      9.780577   10
#
# [2660 rows x 9 columns]

# %%
df.describe().T
# Out:
#                  count       mean        std       min        25%        50%  \
# Length          2660.0   1.423943   0.239300  0.387500   1.287500   1.462500
# Diameter        2660.0   1.116198   0.196878  0.275000   1.000000   1.150000
# Height          2660.0   0.386114   0.094031  0.037500   0.337500   0.387500
# Weight          2660.0  28.817475  12.821337  0.439417  19.855281  28.462898
# Shucked Weight  2660.0  12.421792   5.989869  0.184272   8.093782  12.232809
# Viscera Weight  2660.0   6.307034   2.880555  0.085048   4.323299   6.166016
# Shell Weight    2660.0   8.260565   3.642927  0.141747   5.808104   8.079607
# Age             2660.0  10.915038   3.058831  3.000000   9.000000  10.000000
#
#                       75%        max
# Length           1.587500   2.037500
# Diameter         1.250000   1.625000
# Height           0.437500   2.825000
# Weight          36.560224  80.101512
# Shucked Weight  16.063535  42.184056
# Viscera Weight   8.136306  21.545620
# Shell Weight    10.347568  28.491248
# Age             12.000000  29.000000

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight',
#        'Viscera Weight', 'Shell Weight', 'Age'],
#       dtype='object')

# %%
df['Sex'].mode()
# Out:
# 0    M
# dtype: object

# %%
df['Length'].mode()
df[ 'Length'].median()
# Out:
# 1.4625

# %%
df['Diameter'].mode()
df[ 'Diameter'].median()
# Out:
# 1.15

# %%
df['Height'].mode()
df[ 'Height'].median()
# Out:
# 0.3875

# %%
df['Shucked Weight'].mode()
df[ 'Shucked Weight'].median()
# Out:
# 12.23280925

# %%
df['Viscera Weight'].mode()
df[ 'Viscera Weight'].median()
# Out:
# 6.16601625

# %%
df['Shell Weight'].mode()
df[ 'Shell Weight'].median()
# Out:
# 8.0796075

# %%
df['Age'].mode()
df[ 'Age'].median()
# Out:
# 10.0

# %%
sb.boxplot(df['Age'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sb.boxplot(df['Diameter'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
sb.boxplot(df['Height'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sb.boxplot(df['Weight'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Weight'>

# %%
sb.boxplot(df['Shucked Weight'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shucked Weight'>

# %%
sb.boxplot(df['Viscera Weight'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Viscera Weight'>

# %%
sb.boxplot(df['Shell Weight'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell Weight'>

# %%
sb.boxplot(df['Length'])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
color=['pink', 'purple', 'cyan', 'black']
group_by_diag = df.groupby("Sex").count().reset_index()
sizes = group_by_diag['Age']
labels = group_by_diag['Sex']
plt.pie(sizes , labels= labels, autopct='%1.1f%%', colors=color)
plt.show()

# %%
sb.countplot( x= "Sex" , data = df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df['Age'].plot(kind='hist', bins =20 )
plt.title("age", bbox={'facecolor':'0.8', 'pad':5})
# Out:
# Text(0.5, 1.0, 'age')

# %%
df['Length'].plot(kind='hist' , bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Diameter'].plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Shucked Weight'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Weight'].plot(kind='hist' , bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Height'].plot(kind='hist' ,bins=20 )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Viscera Weight'].plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Shell Weight'].plot(kind='hist' , bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sb.distplot(df["Age"] )
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sb.distplot(df["Length"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sb.distplot(df["Diameter"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sb.distplot(df["Shucked Weight"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shucked Weight', ylabel='Density'>

# %%
sb.distplot(df["Weight"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sb.distplot(df["Height"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sb.distplot(df["Viscera Weight"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Viscera Weight', ylabel='Density'>

# %%
sb.distplot(df["Shell Weight"])
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shell Weight', ylabel='Density'>

# %%
#sb.histplot(df["Length"])

# %%
#sb.histplot(df["Diameter"])

# %%
#sb.histplot(df["Shucked Weight"])

# %%
#sb.histplot(df["Weight"])

# %%
#sb.histplot(df["Height"])

# %%
#sb.histplot(df["Viscera Weight"] )

# %%
LQ1 = np.percentile(df['Length'], 25,
                   interpolation = 'midpoint')
print(LQ1)
 
LQ3 = np.percentile(df['Length'], 75,
                   interpolation = 'midpoint')
print(LQ3)
LIQR = LQ3 - LQ1
print(LIQR)
# Out:
# 1.2875
# 1.5875
# 0.2999999999999998

# %%
DQ1 = np.percentile(df['Diameter'], 25,
                   interpolation = 'midpoint')
print(DQ1)
 
DQ3 = np.percentile(df['Diameter'], 75,
                   interpolation = 'midpoint')
print(DQ3)
DIQR = DQ3 - DQ1
print(DIQR)
# Out:
# 1.0
# 1.25
# 0.25

# %%
HQ1 = np.percentile(df['Height'], 25,
                   interpolation = 'midpoint')
print(HQ1)
 
HQ3 = np.percentile(df['Height'], 75,
                   interpolation = 'midpoint')
print(HQ3)
HIQR = HQ3 - HQ1
print(HIQR)
# Out:
# 0.3375
# 0.4375
# 0.09999999999999998

# %%
WQ1 = np.percentile(df['Weight'], 25,
                   interpolation = 'midpoint')
print(WQ1)
 
WQ3 = np.percentile(df['Weight'], 75,
                   interpolation = 'midpoint')
print(WQ3)
WIQR = WQ3 - WQ1
print(WIQR)
# Out:
# 19.851737375
# 36.563767625
# 16.712030249999998

# %%
Q1 = np.percentile(df['Shucked Weight'], 25,
                   interpolation = 'midpoint')
print(Q1)
 
Q3 = np.percentile(df['Shucked Weight'], 75,
                   interpolation = 'midpoint')
print(Q3)
IQR = Q3 - Q1
print(IQR)
# Out:
# 8.09378225
# 16.067079125
# 7.973296874999999

# %%
Q1 = np.percentile(df['Viscera Weight'], 25,
                   interpolation = 'midpoint')
print(Q1)
 
Q3 = np.percentile(df['Viscera Weight'], 75,
                   interpolation = 'midpoint')
print(Q3)
IQR = Q3 - Q1
print(IQR)
# Out:
# 4.32329875
# 8.1363065
# 3.8130077499999997

# %%
Q1 = np.percentile(df['Shell Weight'], 25,
                   interpolation = 'midpoint')
print(Q1)
 
Q3 = np.percentile(df['Shell Weight'], 75,
                   interpolation = 'midpoint')
print(Q3)
IQR = Q3 - Q1
print(IQR)
# Out:
# 5.804560125
# 10.3475675
# 4.543007375

# %%
zage=stats.zscore(df.Age)

# %%
zage
# Out:
# 0      -0.626186
# 1      -1.607137
# 3      -0.299202
# 5      -0.953170
# 6       1.335716
#           ...
# 3885   -1.280154
# 3886   -0.626186
# 3887    0.027781
# 3888   -0.953170
# 3889   -0.299202
# Name: Age, Length: 2660, dtype: float64

# %%
sb.distplot(zage)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
zlength=stats.zscore(df.Length)

# %%
zlength
# Out:
# 0       0.056665
# 1      -2.242133
# 3      -1.040489
# 5       0.526873
# 6      -0.518035
#           ...
# 3885   -0.988243
# 3886   -0.413544
# 3887    1.362800
# 3888    0.161155
# 3889    0.526873
# Name: Length, Length: 2660, dtype: float64

# %%
sb.distplot(zlength)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
zdiameter=stats.zscore(df.Diameter)

# %%
zdiameter
# Out:
# 0       0.298727
# 1      -2.368404
# 3      -1.161845
# 5       0.235224
# 6      -0.590317
#           ...
# 3885   -0.844329
# 3886   -0.463310
# 3887    1.314778
# 3888    0.108218
# 3889    0.489237
# Name: Diameter, Length: 2660, dtype: float64

# %%
sb.distplot(zdiameter)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
zhieght=stats.zscore(df.Height)

# %%
zhieght
# Out:
# 0       0.280664
# 1      -1.846683
# 3      -1.447806
# 5      -0.384132
# 6      -0.650050
#           ...
# 3885   -0.517091
# 3886   -0.251173
# 3887    0.413623
# 3888   -0.650050
# 3889    0.546582
# Name: Height, Length: 2660, dtype: float64

# %%
sb.distplot(zhieght)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
zwieght=stats.zscore(df.Weight)

# %%
zwieght
# Out:
# 0      -0.326218
# 1      -1.826744
# 3      -1.196456
# 5      -0.012180
# 6      -0.866938
#           ...
# 3885   -1.173235
# 3886   -0.422419
# 3887    1.476183
# 3888   -0.311843
# 3889    0.440079
# Name: Weight, Length: 2660, dtype: float64

# %%
sb.distplot(zwieght)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
zSHwieght=stats.zscore(df['Shucked Weight'])

# %%
zSHwieght
# Out:
# 0      -0.014988
# 1      -1.690753
# 3      -1.281279
# 5       0.193299
# 6      -1.056424
#           ...
# 3885   -1.252876
# 3886   -0.299016
# 3887    1.492727
# 3888   -0.128599
# 3889    0.505730
# Name: Shucked Weight, Length: 2660, dtype: float64

# %%
sb.distplot(zSHwieght)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shucked Weight', ylabel='Density'>

# %%
zVSwieght=stats.zscore(df['Viscera Weight'])

# %%
zVSwieght
# Out:
# 0      -0.250757
# 1      -1.712521
# 3      -1.397528
# 5       0.157750
# 6      -0.157243
#           ...
# 3885   -1.500885
# 3886   -0.181852
# 3887    1.023981
# 3888   -0.157243
# 3889    0.300481
# Name: Viscera Weight, Length: 2660, dtype: float64

# %%
sb.distplot(zVSwieght)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Viscera Weight', ylabel='Density'>

# %%
zShellwieght=stats.zscore(df['Shell Weight'])

# %%
zShellwieght
# Out:
# 0      -0.415509
# 1      -1.839895
# 3      -0.828036
# 5      -0.283189
# 6      -0.944789
#           ...
# 3885   -0.828036
# 3886   -0.361024
# 3887    0.222741
# 3888   -0.516695
# 3889    0.417329
# Name: Shell Weight, Length: 2660, dtype: float64

# %%
sb.distplot(zShellwieght)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shell Weight', ylabel='Density'>

# %%
sb.stripplot(x='Length',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sb.stripplot(x='Diameter',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sb.stripplot(x='Height',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
sb.stripplot(x='Weight',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Weight'>

# %%
sb.stripplot(x='Shucked Weight',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Shucked Weight'>

# %%
sb.stripplot(x='Viscera Weight',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Viscera Weight'>

# %%
sb.stripplot(x='Shell Weight',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Shell Weight'>

# %%
sb.stripplot(x='Age',data=df,alpha=.3,size=4)
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
dfOut3=df[df.Weight>(WQ3 + 1.5 * WIQR)]
dfOut3.Weight
# Out:
# 84      67.500159
# 229     72.432973
# 501     71.610837
# 538     72.234526
# 610     62.950065
# 748     62.652395
# 772     78.797435
# 853     63.375307
# 1142    63.786375
# 1204    70.661129
# 1291    65.870063
# 1326    71.114721
# 1485    63.928123
# 1555    64.169093
# 1609    67.982101
# 1757    71.313167
# 1812    62.212978
# 1949    62.652395
# 2061    65.260549
# 2316    66.068510
# 2387    63.389482
# 2484    62.397250
# 2571    75.324622
# 2716    72.291225
# 2725    62.354725
# 2838    64.339190
# 2896    80.101512
# 3069    61.901133
# 3185    71.015497
# 3196    67.500159
# 3350    66.139383
# 3555    64.438413
# 3681    63.105987
# 3815    70.845400
# Name: Weight, dtype: float64

# %%
dfOut2=df[df.Weight< (WQ1 - 1.5 * WIQR)]
dfOut2.Weight
# Out:
# Series([], Name: Weight, dtype: float64)

# %%
dfOut5=df[df.Length>(LQ3 + 1.5 * LIQR)]
dfOut5.Length
# Out:
# 1485    2.0375
# Name: Length, dtype: float64

# %%
dfOut6=df[df.Length< (LQ1 - 1.5 * LIQR)]
dfOut6.Length
# Out:
# 10      0.8250
# 70      0.7000
# 115     0.6750
# 122     0.6875
# 250     0.7625
#          ...
# 3395    0.8250
# 3406    0.7250
# 3550    0.8000
# 3844    0.5875
# 3854    0.6500
# Name: Length, Length: 63, dtype: float64

# %%
dfOut5=df[df.Diameter>(DQ3 + 1.5 * DIQR)]
dfOut5.Diameter
# Out:
# Series([], Name: Diameter, dtype: float64)

# %%
dfOut6=df[df.Diameter< (DQ1 - 1.5 * DIQR)]
dfOut6.Diameter
# Out:
# 10      0.5375
# 70      0.5125
# 115     0.4875
# 122     0.5125
# 250     0.5750
# 591     0.6000
# 624     0.4875
# 670     0.5375
# 693     0.2875
# 791     0.4750
# 825     0.5250
# 845     0.5625
# 850     0.4875
# 896     0.4875
# 901     0.3500
# 931     0.5875
# 1031    0.6125
# 1098    0.5000
# 1132    0.4500
# 1225    0.5250
# 1245    0.5625
# 1289    0.3625
# 1351    0.3750
# 1416    0.5500
# 1523    0.5000
# 1660    0.3875
# 1681    0.5625
# 1685    0.6000
# 1703    0.6125
# 2076    0.5250
# 2090    0.5625
# 2218    0.5875
# 2299    0.5750
# 2558    0.5250
# 2598    0.5750
# 2610    0.6000
# 2627    0.4500
# 2638    0.4000
# 2765    0.2750
# 2835    0.3125
# 2889    0.5000
# 2958    0.5875
# 3040    0.5625
# 3137    0.3375
# 3178    0.5625
# 3182    0.5375
# 3225    0.6125
# 3278    0.5000
# 3381    0.6000
# 3406    0.5750
# 3550    0.6000
# 3695    0.5875
# 3844    0.4250
# 3854    0.5000
# Name: Diameter, dtype: float64

# %%
dfOut5=df[df.Height>(HQ3 + 1.5 * HIQR)]
dfOut5.Height
# Out:
# 748     1.2875
# 772     0.6250
# 776     0.6000
# 1326    0.5875
# 1331    0.5875
# 1485    0.6250
# 1949    0.6000
# 2038    0.5875
# 2256    2.8250
# 2588    0.6250
# 2725    0.6000
# 3055    0.5875
# Name: Height, dtype: float64

# %%
dfOut6=df[df.Height< (HQ1 - 1.5 * HIQR)]
dfOut6.Height
# Out:
# 10      0.1875
# 122     0.1750
# 624     0.1750
# 670     0.1875
# 693     0.0625
# 791     0.1875
# 825     0.1875
# 845     0.1875
# 850     0.1750
# 896     0.1625
# 901     0.1375
# 931     0.1500
# 1127    0.1625
# 1132    0.1625
# 1245    0.1875
# 1257    0.1875
# 1289    0.1250
# 1351    0.1250
# 1416    0.1750
# 1660    0.1125
# 1898    0.1875
# 2076    0.1875
# 2090    0.1750
# 2558    0.1625
# 2627    0.1625
# 2638    0.1500
# 2765    0.1000
# 2835    0.1000
# 2889    0.1625
# 3137    0.1000
# 3140    0.1875
# 3182    0.1875
# 3225    0.1875
# 3349    0.1625
# 3381    0.1875
# 3406    0.1875
# 3542    0.0375
# 3844    0.1375
# 3854    0.1625
# Name: Height, dtype: float64

# %%
AgeRange=df.Age.max()-df.Age.min()
print("Range of Age =",AgeRange)
# Out:
# Range of Age = 26

# %%
ShellWeightRange=df['Shell Weight'].max()-df['Shell Weight'].min()
print("Range of Shell Weight =",ShellWeightRange)
# Out:
# Range of Shell Weight = 28.3495

# %%
VisceraWeightRange=df['Viscera Weight'].max()-df['Viscera Weight'].min()
print("Range of Viscera Weight =",VisceraWeightRange)
# Out:
# Range of Viscera Weight = 21.4605715

# %%
ShuckedWeightRange=df['Shucked Weight'].max()-df['Shucked Weight'].min()
print("Range of Shucked Weight =",ShuckedWeightRange)
# Out:
# Range of Shucked Weight = 41.99978425

# %%
WeightRange=df.Weight.max()-df.Weight.min()
print("Range of Weight =",WeightRange)
# Out:
# Range of Weight = 79.662095

# %%
HeightRange=df.Height.max()-df.Height.min()
print("Range of Height =",HeightRange)
# Out:
# Range of Height = 2.7875

# %%
DiameterRange=df.Diameter.max()-df.Diameter.min()
print("Range of Diameter =",DiameterRange)
# Out:
# Range of Diameter = 1.35

# %%
LengthRange=df.Length.max()-df.Length.min()
print("Range of Length =",LengthRange)
# Out:
# Range of Length = 1.6500000000000001

# %%
x = df['Shell Weight']
y = df['Age']

# %%
def linear_regression(x, y):     
    N = len(x)
    x_mean = x.mean()
    y_mean = y.mean()
    
    b1_num = ((x - x_mean) * (y - y_mean)).sum() #lec 3 slide 70
    b1_den = ((x - x_mean)**2).sum()
    b1 = b1_num / b1_den
    
    b0 = y_mean - (b1*x_mean)
    
    reg_line ='y = {} + {}β'.format(b0, round(b1, 3))
    
    return (b0, b1, reg_line)

# %%
def corr_coef(x, y):
    N = len(x)
    
    num = (N * (x*y).sum()) - (x.sum() * y.sum())
    den = np.sqrt((N * (x**2).sum() - x.sum()**2) * (N * (y**2).sum() - y.sum()**2))
    R = num / den
    return R

# %%
def predict(b0, b1, new_x):
    yhat = b0 + b1 * new_x
    return yhat

# %%
def Error (y,predict):
    Error=abs(y-predict)
    return Error

# %%
linear_regression(x, y)
# Out:
# (7.724845227392523, 0.38619543350878155, 'y = 7.724845227392523 + 0.386β')

# %%
b0, b1, reg_line = linear_regression(x, y)
print('Regression Line: ', reg_line)
R = corr_coef(x, y)
print('Correlation Coef.: ', R)
print('Coefficient of determination: ', R**2)
# Out:
# Regression Line:  y = 7.724845227392523 + 0.386β
# Correlation Coef.:  0.45994092184075985
# Coefficient of determination:  0.21154565158372796

# %%
plt.figure(figsize=(12,5))
plt.scatter(x, y,  linewidths=1, edgecolor='black')
text = '''X Mean: {} Years
Y Mean: {}
R: {}
R^2: {}
y = {} + {}X'''.format(round(x.mean(), 2), 
                       round(y.mean(), 2), 
                       round(R, 4), 
                       round(R**2, 4),
                       round(b0, 3),
                       round(b1, 3))
plt.text(x=0, y=23, s=text, fontsize=10, bbox={'facecolor': 'grey', 'alpha': 0.2, 'pad': 3})
plt.xlabel('Shell Weight', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.plot(x, b0 + b1*x, c = 'r', linewidth=5, alpha=.5, solid_capstyle='round')
plt.scatter(x=x.mean(), y=y.mean(), marker='*', s=10**2.5, c='r') # average point

# %%
predict(b0,b1,x)
# Out:
# 0       10.330576
# 1        8.327010
# 3        9.750308
# 5       10.516699
# 6        9.586081
#           ...
# 3885     9.750308
# 3886    10.407215
# 3887    11.228348
# 3888    10.188246
# 3889    11.502060
# Name: Shell Weight, Length: 2660, dtype: float64

# %%
Error(y,predict(b0,b1,x))
# Out:
# 0       1.330576
# 1       2.327010
# 3       0.249692
# 5       2.516699
# 6       5.413919
#           ...
# 3885    2.750308
# 3886    1.407215
# 3887    0.228348
# 3888    2.188246
# 3889    1.502060
# Length: 2660, dtype: float64

# %%
df.var()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_11232/1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Length              0.057265
# Diameter            0.038761
# Height              0.008842
# Weight            164.386688
# Shucked Weight     35.878530
# Viscera Weight      8.297596
# Shell Weight       13.270916
# Age                 9.356449
# dtype: float64
